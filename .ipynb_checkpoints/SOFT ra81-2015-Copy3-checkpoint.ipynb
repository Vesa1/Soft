# %% [markdown]
# # **Detekcija linija**
#
# U ovom odeljku se vrši detekcija linija. Posmatra se prvi frejm i pomoću Canny algoritma se detektuju ivice na slici. Potrebno je ovo uraditi samo na jednom frejmu od svakog videa jer linije uvek imaju isti položaj tokom videa. Ujedno, to predstavlja predprocesiranje za Hough transformaciju. Nakon toga se vrši Hough transformacija, koja nam daje četiri prave, tačnije tačke kojima su određene prave. Povratna vrednost su četiri prave, po dve za svaku liniju koja treba da se detektuje.

# %%
def detekcijaLinija(video):
    cap = cv2.VideoCapture(video) #Ucitavanje videa
    success, frejm = cap.read() #Image -> frame
    count = 0
    success = True
    ret = []
    while success:
      success, frejm = cap.read()
      if count == 0: #Prvi frejm
        ivice = cv2.Canny(frejm,100,200) #Nalazenje ivica
        
        linije = cv2.HoughLinesP(ivice,1,np.pi/180,100,minLineLength=199,maxLineGap=10) #Detektovanje linija
        for linija in linije:
            x1, y1, x2, y2 = linija[0]
            tacka = []
            tacka.append(x1)
            tacka.append(y1)
            tacka.append(x2)
            tacka.append(y2)
            ret.append(tacka);
            cv2.line(frejm, (x1, y1), (x2, y2), (0, 255, 255), 1)
            #cv2.imshow('frame',image)
        cv2.waitKey(0)
        
      count += 1
    cap.release()
    cv2.destroyAllWindows()
    return ret

# %%
def dilate(image):
    kernel = np.ones((3,3)) # strukturni element 2x2 blok
    return cv2.dilate(image, kernel, iterations=1)
def erode(image):
    kernel = np.ones((3,3)) # strukturni element 3x3 blok
    return cv2.erode(image, kernel, iterations=1)

# %% [markdown]
# # **Detekcija brojeva**
# U ovom odeljku je odrađena detekcija brojeva. U funckiji detekcijaBrojeva se detektuju svi brojevi u frejmu, dok se šum i linije zanemaruju. Broj se dalje šalje neuronskoj mreži, kako bi se odredilo koji je tačno broj u pitanju.

# %%
def detekcijaBrojeva(video, plavaLinija):
    cap = cv2.VideoCapture(video) #Ucitavanje videa
    count = 0
    resenje = 0
    ret = []
    retBr = []
    while True:
        success, image = cap.read()
        if not success: 
            break
        gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) #Siva slika
        
        ret,gray = cv2.threshold(gray,200,255,0) #Sve sto nije bela boja se brise, tj dobijaju se samo brojevi
        gray2 = gray.copy()
        samoBrojevi = Image.fromarray(gray2, 'L') #Samo brojevi na frejmu 
        #samoBrojevi.show() #Prikaz brojeva sa frejma 
        konture, hier = cv2.findContours(gray2,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
        for kontura in konture:
            if 1<cv2.contourArea(kontura)<200:
                (x,y,sirina,visina) = cv2.boundingRect(kontura)
                if(visina>11): 
                    #cv2.rectangle(image,(x-7,y-7),(x+sirina+7,y+visina+7),(0, 255, 0),1, 1) 
                    samoBrojevi = np.array(samoBrojevi)
                    broj = samoBrojevi[y-4:y+visina+4,x-9:x+sirina+9]
                    broj = Image.fromarray(broj)
                    broj = broj.resize((28, 28))
                    #broj.show()
                    slika = broj.convert("L")
                    imgarr = np.array(slika)
                    imgarr = imgarr.reshape(1, 28*28)
                    imgarr = dilate(dilate(imgarr))
                    imgarr = imgarr.astype('float32')
                    imgarr /= 255
                    predicted_classes = mnist_model.predict_classes(imgarr)
                    x = Broj(kontura, predicted_classes, count, x, y, sirina, visina, 0)
                    ret = dodajeSeUListuMogucihPrelazaka(image, x, plavaLinija)
                    if ret is not None: 
                        resenje += ret
        gray2 = dilate(dilate(gray2))
        cv2.imshow('brojevi', image)
        #display_video(image)
        cv2.waitKey(1)
        count += 1
    cap.release()
    cv2.destroyAllWindows()
    return gray2, resenje

# %%
import time
def dodajeSeUListuMogucihPrelazaka(image, x, plavaLinijaVideo1):
    uspeo = 0
    ret = 0
    if not moguciBrojevi:
        moguciBrojevi.append(x)
    for i, broj in enumerate(moguciBrojevi):
        try: 
            istiBroj = distance((broj.x, 0, broj.y), (x.x, 0, x.y))
            #print(proba)
            if(istiBroj<10):
                x.presao = broj.presao
                moguciBrojevi[i] = x
                uspeo = 1
                return
        except: 
            uspeo = 0

    if(uspeo == 0):
            moguciBrojevi.append(x)
    #print("----------------------------------------------")
    for j, br in enumerate(moguciBrojevi):
        #print(moguciBrojevi[j])
        if(br.x > plavaLinijaVideo1[0] and br.x < plavaLinijaVideo1[2]):
            start = (plavaLinijaVideo1[0], 0, plavaLinijaVideo1[1])
            end = (plavaLinijaVideo1[2], 0, plavaLinijaVideo1[3])
            line_vec = vector(start, end)
            tacka = (br.x + br.width, 0, br.y + br.height)
            dist, nearest = pnt2line(tacka, start, end) 
            #cv2.line(image,(br.x + br.width,br.y + br.height),(int(nearest[0]), int(nearest[2])),(255,0,0),1)
            if(dist < 15 and dist >= 0  and br.presao == 0 and br.x < int(nearest[0])):
                print(br.x + br.width, 0, br.y + br.height)
                print(nearest)
                moguciBrojevi[j].presao = 1
                cv2.rectangle(image,(br.x-8,br.y-8),(br.x+br.width+8,br.y+br.height+8),(0, 255, 0),1, 1)
                print(int(moguciBrojevi[j].predikcija))
                ret += int(moguciBrojevi[j].predikcija)
                time.sleep(1)
    return ret

# %%
def pnt2line(pnt, start, end):
    line_vec = vector(start, end)
    pnt_vec = vector(start, pnt)
    line_len = length(line_vec)
    line_unitvec = unit(line_vec)
    pnt_vec_scaled = scale(pnt_vec, 1.0/line_len)
    t = dot(line_unitvec, pnt_vec_scaled)    
    if t < 0.0:
        t = 0.0
    elif t > 1.0:
        t = 1.0
    nearest = scale(line_vec, t)
    dist = distance(nearest, pnt_vec)
    nearest = add(nearest, start)
    return (dist, nearest)

# %%
class resenjaVidea:
    def __init__(nazivVidea, resenje):
        self.nazivVidea = nazivVidea
        self.resenje= resenje

# %%
class Broj:
    def __init__(self, kontura, predikcija, frame, x, y, width, height, presao):
        self.kontura = kontura
        self.predikcija= predikcija
        self.frame = frame
        self.x = x
        self.y = y
        self.width = width
        self.height = height
        self.presao = presao
    def __repr__(self):
         return "<Test predikcija:%s frame:%s presao:%s> " % (self.predikcija, self.frame, self.presao)
    def __str__(self):
         return "<Test predikcija:%s frame:%s presao:%s x:%s y:%s> " % (self.predikcija, self.frame, self.presao, self.x, self.y)

# %%
import math
  
def dot(v,w):
    x,y,z = v
    X,Y,Z = w
    return x*X + y*Y + z*Z
  
def length(v):
    x,y,z = v
    return math.sqrt(x*x + y*y + z*z)
  
def vector(b,e):
    x,y,z = b
    X,Y,Z = e
    return (X-x, Y-y, Z-z)
  
def unit(v):
    x,y,z = v
    mag = length(v)
    return (x/mag, y/mag, z/mag)
  
def distance(p0,p1):
    return length(vector(p0,p1))
  
def scale(v,sc):
    x,y,z = v
    return (x * sc, y * sc, z * sc)
  
def add(v,w):
    x,y,z = v
    X,Y,Z = w
    return (x+X, y+Y, z+Z)

# %%
def procenti():
    res = []
    n = 0
    with open('res.txt') as file:	
        data = file.read()
        lines = data.split('\n')
        for id, line in enumerate(lines):
            if(id>0):
                cols = line.split('\t')
                if(cols[0] == ''):
                    continue
                cols[1] = cols[1].replace('\r', '')
                res.append(float(cols[1]))
                n += 1

    correct = 0
    student = []
    student_results = []
    with open("out.txt") as file:
        data = file.read()
        lines = data.split('\n')
        for id, line in enumerate(lines):
            cols = line.split('\t')
            if(cols[0] == ''):
                continue
            if(id==0):
                student = cols  
            elif(id>1):
                cols[1] = cols[1].replace('\r', '')
                student_results.append(float(cols[1]))

    diff = 0
    for index, res_col in enumerate(res):
        diff += abs(res_col - student_results[index])
    percentage = 100 - abs(diff/sum(res))*100

    print (student)
    print ('Procenat tacnosti:\t'+str(percentage))
    print ('Ukupno:\t'+str(n))

# %%
def treniranjeModela():
    pathname = os.path.dirname(sys.argv[0])   
    fullpath = os.path.abspath(pathname)

    print (fullpath) #Za cuvanje obucenog modela

    #MNIST baza 
    (X_train, y_train), (X_test, y_test) = mnist.load_data()

    #Primeri brojeva iz MNIST
    fig = plt.figure()
    for i in range(3):
      plt.subplot(3,3,i+1)
      plt.tight_layout()
      plt.imshow(X_train[i], cmap='gray', interpolation='none')
      plt.title("Digit: {}".format(y_train[i]))
      plt.xticks([])
      plt.yticks([])
    fig

    vracanje = np.empty_like(X_train[0])
    for i, tr in enumerate(X_train):
        X_train[i] = dilate(X_train[i])
        slika = Image.fromarray(X_train[i])
        #slika.show()
        konture, hier = cv2.findContours(X_train[i],cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
        kontura = konture[0]
            if (1<cv2.contourArea(kontura)<100):
                (x,y,sirina,visina) = cv2.boundingRect(kontura)
                print(x, y, sirina, visina)
                isecen = X_train[i][y:y+visina,x:x+sirina]
                slika = Image.fromarray(isecen)
                #br = slika.resize((28, 28))
                slika.show()
                if(np.shape(slika)!=(28,28)):
                    img = np.zeros((28,28))
                    x = 28 - np.shape(slika)[0]
                    y = 28 - np.shape(slika)[1]
                    img[:-x,:-y] = slika
                    X_train[i] = img
                else:
                    X_train[i] = slika
                    #return slika.show()
    
    # building the input vector from the 28x28 pixels
    X_train = X_train.reshape(60000, 784)
    X_test = X_test.reshape(10000, 784)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')

    # normalizing the data to help with the training
    X_train /= 255
    X_test /= 255
    
    print(np.unique(y_train, return_counts=True))


    # one-hot encoding using keras' numpy-related utilities
    n_classes = 10
    Y_train = np_utils.to_categorical(y_train, n_classes)
    Y_test = np_utils.to_categorical(y_test, n_classes)

    # building a linear stack of layers with the sequential model
    model = Sequential()
    model.add(Dense(512, input_shape=(784,)))
    model.add(Activation('relu'))                            
    model.add(Dropout(0.2))

    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.2))

    model.add(Dense(10))
    model.add(Activation('softmax'))


    # compiling the sequential model
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

    # training the model and saving metrics in history
    history = model.fit(X_train, Y_train,
              batch_size=128, epochs=20,
              verbose=2,
              validation_data=(X_test, Y_test))

    # saving the model
    model_name = 'keras_mnist.h5'
    model_path = os.path.join(fullpath, model_name)
    model.save(model_path)
    print('Model je sacuvan na ovoj lokaciji: %s ' % model_path)
    return X_test, Y_test, y_test
# Out:
#   File "<ipython-input-161-dc21b9d2698f>", line 28
#     if (1<cv2.contourArea(kontura)<100):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # **Main**
# Ovaj segment predstavlja main programa. Prvo se vrši detekcija linija. Kao glavna prava se uzima ona koja je ispod, jer je potrebno da broj pređe preko nje kako bi bio sumiran.

# %%
import cv2
import numpy as np
from numpy import array
import matplotlib
import sys, os
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import random
from skimage.color import rgb2gray
from skimage import color

from keras.datasets import mnist
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils

#X_test, Y_test, y_test= treniranjeModela()

mnist_model = load_model("keras_mnist.h5") #Iscitavanje sacuvanog modela

videi = ['video-0.avi', 'video-1.avi', 'video-2.avi', 'video-3.avi', 'video-4.avi', 'video-5.avi', 'video-6.avi', 'video-7.avi', 'video-8.avi', 'video-9.avi']
#videi = ['video-8.avi']
res = []

for i in videi:
    moguciBrojevi = []
    resenje = 0
    linijeVideo = detekcijaLinija(i)
    plavaLinijaVideo = linijeVideo[0]
    brojevi, resenje = detekcijaBrojeva(i, plavaLinijaVideo)
    print('Za video ', i, ' resenje je: ', resenje)
    res.append(resenje)
    for br in moguciBrojevi:
        print(br)

with open ('out.txt', 'w') as outfile:
    outfile.write('RA 81/2015 Jelena Vesovic\nfile sum\n')
    for i in range(0,len(res)):
        sumica = float(res[i])
        outfile.write(videi[i] +'\t'+ str(sumica) + '\n')
    
procenti()
# Out:
# 348 0 158
# (347.73791818601615, 0.0, 157.6528717695578)
# 1
# 450 0 83
# (448.77134122068117, 0.0, 81.3726373783857)
# 0
# 346 0 165
# (343.0978646836834, 0.0, 161.15611216381905)
# 1
# 490 0 39
# (489.0, 0.0, 51.0)
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-41dfa1a762e6> in <module>
#      30     linijeVideo = detekcijaLinija(i)
#      31     plavaLinijaVideo = linijeVideo[0]
# ---> 32     brojevi, resenje = detekcijaBrojeva(i, plavaLinijaVideo)
#      33     print('Za video ', i, ' resenje je: ', resenje)
#      34     res.append(resenje)
#
# <ipython-input-152-b504c99af800> in detekcijaBrojeva(video, plavaLinija)
#      32                     imgarr = imgarr.astype('float32')
#      33                     imgarr /= 255
# ---> 34                     predicted_classes = mnist_model.predict_classes(imgarr)
#      35                     x = Broj(kontura, predicted_classes, count, x, y, sirina, visina, 0)
#      36                     ret = dodajeSeUListuMogucihPrelazaka(image, x, plavaLinija)
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     265             A numpy array of class predictions.
#     266         """
# --> 267         proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     268         if proba.shape[-1] > 1:
#     269             return proba.argmax(axis=-1)
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1434         run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#    1435         # TODO(mrry): Switch to raising an exception from the SWIG wrapper.
# -> 1436         with errors.raise_exception_on_not_ok_status() as status:
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\errors_impl.py in __enter__(self)
#     517
#     518   def __enter__(self):
# --> 519     self.status = c_api_util.ScopedTFStatus()
#     520     return self.status.status
#     521
#
# c:\users\jelena\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\c_api_util.py in __init__(self)
#      31
#      32   def __init__(self):
# ---> 33     self.status = c_api.TF_NewStatus()
#      34
#      35   def __del__(self):
#
# KeyboardInterrupt:
